# %% [markdown]
# İnsan Resursları (İR) Analitiki olaraq **Excel** və **Power BI** kimi alətlərdə edə biləcəyiniz işlər çox genişdir. Bu alətlərlə **İR metrikalarının ölçülməsi**, **trendlərin təhlili**, **vizual dashboard-ların qurulması**, **proqnozlar** və **data-driven qərarların verilməsi** mümkündür.
#
# Aşağıda **Excel** və **Power BI** üçün konkret nümunələri və bacarıqları təqdim edirəm:
#
# ---
#
# ### ✅ **Excel-də HR Analitikası üçün Edilə Biləcək İşlər:**
#
# | Bacarıq / Funksiya                                      | Təsviri                                                                                       |
# | ------------------------------------------------------- | --------------------------------------------------------------------------------------------- |
# | **Pivot Table**                                         | İşçi dövriyyəsi, işə qəbul, performans və s. göstəricilərin qruplaşdırılması və təhlili.      |
# | **Conditional Formatting**                              | Aylıq performansda azalma, gecikmələr və ya yüksək fluktuasiyanı vizual göstərmək.            |
# | **LOOKUP funksiyaları (VLOOKUP, XLOOKUP, INDEX-MATCH)** | Məlumatlar arasında əlaqə qurmaq (məs., işçi adı ilə maaş və ya şöbə tapmaq).                 |
# | **IF, IFS, COUNTIF, SUMIF**                             | Məsələn, “kaç nəfər 6 aydan az işləyir?” sualına cavab tapmaq.                                |
# | **Trend Analizi**                                       | Zaman seriyası ilə əməkdaş sayındakı dəyişiklikləri vizuallaşdırmaq (Line chart, sparklines). |
# | **Statistik analiz**                                    | Ortalama, standart sapma, korrelyasiya, regresiya analizi (Data Analysis Toolpak ilə).        |
# | **Dashboard yaradılması**                               | KPI-ları (işə qəbul sürəti, dövriyyə faizi, təlim saatları və s.) vizual olaraq göstərmək.    |
# | **Məntiqi testlər və nəzarət siyahıları**               | Məlumat keyfiyyətini yoxlamaq üçün (məsələn, doğum tarixi gələcək tarixdirsə xəbərdarlıq).    |
#
# ---
#
# ### ✅ **Power BI-də HR KPI və Dashboard-lar:**
#
# | Metrika / Dashboard Elementi           | İzah                                                                   |
# | -------------------------------------- | ---------------------------------------------------------------------- |
# | **Headcount Over Time**                | Əməkdaş sayındakı aylıq və ya rüblük dəyişikliklər.                    |
# | **Attrition Rate (Kadr axını)**        | Giden işçilərin faizi, könüllü və qeyri-könüllü ayrılmalar.            |
# | **Hiring Funnel**                      | İşə qəbul mərhələləri: müraciət edən → müsahibə → təklif → qəbul edən. |
# | **Diversity Dashboard**                | Cinsiyyət, yaş qrupu, region, etnik müxtəliflik və s. göstəricilər.    |
# | **Time to Hire**                       | Bir vakansiyanın bağlanma müddəti (orta gün sayında).                  |
# | **Employee Tenure Analysis**           | İşçilərin şirkətdə keçirdiyi ortalama müddət (tenure).                 |
# | **Performance vs Tenure Scatterplot**  | Performans nəticələri ilə şirkətdə qalma müddətinin əlaqəsi.           |
# | **Absenteeism Rate**                   | İşdən qalma faizi və gün sayı (şöbə üzrə müqayisə).                    |
# | **Training Hours / Cost per Employee** | Təlim göstəriciləri, ROI analizi.                                      |
# | **Custom Slicers & Filters**           | Şöbə, region, vəzifə, status və s. üzrə analitikləri filtreləmək.      |
#
# ---
#
# ### 🎯 Misal üçün KPI-lar (Excel və ya Power BI-də göstərə bilərsiniz):
#
# | KPI Adı                         | Formula / İstifadə                                               |
# | ------------------------------- | ---------------------------------------------------------------- |
# | **Attrition Rate**              | (Ayrılan əməkdaşların sayı / Başlanğıc headcount) × 100          |
# | **Average Tenure**              | İşdə qalma müddətləri ortalaması                                 |
# | **Time to Fill**                | İşə qəbul tarixindən təklifə qədər gün sayı                      |
# | **Offer Acceptance Rate**       | (Qəbul edilən təkliflərin sayı / Verilən təkliflərin sayı) × 100 |
# | **Training Hours per Employee** | (Ümumi təlim saatları / əməkdaş sayı)                            |
# | **Absenteeism Rate**            | (Qaçırılan iş günləri / ümumi iş günləri) × 100                  |
#
# ---
#
# ### 📌 İR Analitikasında Excel və Power BI istifadə ssenariləri:
#
# 1. **Aylıq rəhbər hesabatı** – headcount, attrition, işə qəbul və s.
# 2. **Performance vs Pay scatterplot** – əmək haqqı ilə performansın əlaqəsi.
# 3. **İşə qəbul effektivliyi** – hansı mənbədən gələn namizədlər daha uğurludur?
# 4. **Proqnoz modelləri (Excel və ya Python ilə)** – gələcəkdə neçə nəfər işdən çıxa bilər?
# 5. **Turnover səbəblərinin təhlili** – könüllü və qeyri-könüllü səbəblərin vizualizasiyası.

# %% [markdown]
# Bravo Supermarket kimi böyük bir pərakəndə satış şirkəti üçün **HR analitikası** qurarkən əsas məqsəd aşağıdakı suallara **data əsaslı cavab** tapmaq və **daxili İR strategiyasını təkmilləşdirmək** olmalıdır:
#
# ---
#
# ## 🧭 **Əsas Məqsəd:**
#
# İşçi axını, performans, müxtəliflik və işə qəbul göstəriciləri üzərində **nəzarət**, **təhlil** və **proqnoz** apararaq Bravo-nun HR siyasətlərinə **strateji töhfə vermək**.
#
# ---
#
# ## 🔎 Bravo Supermarket üçün HR Analizi - Bölmələr üzrə Təhlil
#
# ### 1. 📊 **Kadr Axını (Turnover Analysis)**
#
# | Suallar                                          | Təhlil ediləcək göstəricilər |
# | ------------------------------------------------ | ---------------------------- |
# | Ən çox axın hansı mağazada / regiondadır?        | Mağaza üzrə turnover rate    |
# | Könüllü və qeyri-könüllü çıxışlar necə paylanır? | Termination reason (%)       |
# | Axın hansı mövsümdə artır?                       | Aylar üzrə ayrılmalar        |
# | Yeni işçilər hansı müddətdən sonra çıxır?        | "Tenure before exit"         |
#
# ### 2. 👷 **İşçi Heyəti və Struktur (Workforce Analysis)**
#
# | Göstəricilər                       | Təhlil növü              |
# | ---------------------------------- | ------------------------ |
# | Headcount by store, region, gender | Pivot Table / Bar Chart  |
# | Tam ştat vs yarımştat              | Sütun qrafiki            |
# | Yaş bölgüsü, gender müxtəlifliyi   | Diversity pie chart      |
# | Shift sistemi üzrə yayılma         | Shift paylanması heatmap |
#
# ### 3. 🧲 **İşə Qəbul Təhlili (Recruitment Funnel)**
#
# | Suallar                                          | Vizual Təqdimat                 |
# | ------------------------------------------------ | ------------------------------- |
# | Hər mağaza üçün orta "Time to Hire" nə qədərdir? | Line chart                      |
# | Ən effektiv namizəd mənbəyi hansıdır?            | Source comparison bar chart     |
# | Verilən təkliflərin neçə faizi qəbul olunur?     | Offer acceptance rate KPI       |
# | Hansı rollar üçün işə qəbul çətindir?            | Position-wise funnel conversion |
#
# ### 4. 📈 **Performans və Təlim (Performance & Training)**
#
# | Nəyi təhlil edirik?                                  | Necə göstərilir? |
# | ---------------------------------------------------- | ---------------- |
# | İşçinin performansı və təlim saatları arasında əlaqə | Scatterplot      |
# | Təlim saatları şöbə üzrə necə paylanır?              | Bar chart        |
# | Təlimin ROI-si nə qədərdir?                          | KPI + insight    |
#
# ### 5. 📅 **İş Qalma Müddəti (Tenure Analysis)**
#
# | Təhlil                                | İstifadə          |
# | ------------------------------------- | ----------------- |
# | Orta tenure                           | Headcount/tenure  |
# | 6 aydan az işləyib çıxanlar           | Early turnover %  |
# | Şöbə və vəzifə üzrə tenure müqayisəsi | Heatmap/Bar Chart |
#
# ---
#
# ## 📊 Vizual HR Dashboard (Power BI və ya Excel)
#
# Aşağıdakı göstəriciləri əks etdirən **dinamik dashboard** hazırlana bilər:
#
# ### 🎯 **KPI Paneli** (üst hissədə):
#
# * 🔹 Headcount (Toplam)
# * 🔹 Attrition Rate (%)
# * 🔹 Time to Hire (orta gün)
# * 🔹 Offer Acceptance Rate (%)
# * 🔹 Training Hours per Employee
# * 🔹 Avg. Tenure (il)
#
# ### 🗺️ **Interaktiv Vizual Analizlər**:
#
# * 📍 Mağaza üzrə headcount xəritəsi
# * 📉 Aylıq axın trendi
# * 🎯 Gender və yaş müxtəlifliyi
# * 🕐 İşə qəbul funnel: müraciət → təklif → qəbul
# * 📈 Performans və təlim əlaqəsi
#
# ---
#
# ## 🧠 İR Analitikasına Əsaslanaraq Tövsiyələr (Insight & Action)
#
# | Təhlil                         | Tövsiyə                                     |
# | ------------------------------ | ------------------------------------------- |
# | Gənc işçilər tez çıxır         | Onboarding proqramı gücləndirilsin          |
# | Filial A-da axın çoxdur        | Menecer/şərtlər təhlil olunsun              |
# | Time to Hire yüksəkdir         | İşə qəbul prosesi optimallaşdırılsın        |
# | Gender müxtəlifliyi zəifdir    | Dəyişkən namizəd mənbələri istifadə olunsun |
# | Shift sistemində disbalans var | Ədalətli növbə bölüşdürülməsi aparılsın     |
#
# ---
#
# ## ⚙️ Texniki Mühit:
#
# | Alət                    | İstifadə                               |
# | ----------------------- | -------------------------------------- |
# | **Excel**               | Data təmizləmə, pivot table, qrafik    |
# | **Power BI**            | KPI dashboard, interaktiv filtrelər    |
# | **SQL**                 | İR datasının çıxarılması (HRIS-dən)    |
# | **Python (əgər varsa)** | Proqnozlaşdırma (Attrition), regresiya |

# %%
from matplotlib import pyplot

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.boxplot()
