# %% [markdown]
# # Dərs 3 Əlavə

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Power BI\Fusion Academy\Pictures\Ders3_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(22, 33):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Table View-da göz-ü klik etsən Report View-da həmin 
                     Table görsənməyəcək""", fontsize=18,fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Parameter Slicer - Sütunlar üzrə filter (New parameter)""", fontsize=18,fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Parameter Slicer tətbiqi""", fontsize=18,fontweight='bold')
    if i == 3:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""Yeni Cədvəl Yaratmaq və DAX: LOOKUPVALUE ilə 
                     Cədvəlləri Join etmək""", fontsize=18,fontweight='bold')
    if i == 4:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""DAX: LOOKUPVALUE ilə Cədvəlləri Join etmək""", fontsize=18,fontweight='bold')
    if i == 5:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""Yeni Cədvəl üçün Revenue tapmaq""", fontsize=18,fontweight='bold')
    if i == 6:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""Revenue başqa Cədvəldə olduğu Müştəri İD -ni də LOOKUPVALUE ilə 
                gətirib sonra Model View-də Cədvəlləri Join etmək lazımdır""", fontsize=18,fontweight='bold')
    if i == 7:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""Model View-də Cədvəlləri Join edəndən sonra Revenue 
                     uyğun bölündü""", fontsize=18,fontweight='bold')
    if i == 8:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""DAX: SUMMARIZECOLUMNS ilə Yeni Table yaratmaq""", fontsize=18,fontweight='bold')
    if i == 9:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""Power Query-də Transform ---> Time --->Hour""", fontsize=18,fontweight='bold')
    if i == 10:
        plt.figure(figsize=(11, 7))  # Şəkilin ölçüsü
        plt.title("""Power Query-də Transform ---> Fill --->Down -  Boş xanları 
                     aşağıya doğru doldurmaq""", fontsize=18,fontweight='bold')         
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
