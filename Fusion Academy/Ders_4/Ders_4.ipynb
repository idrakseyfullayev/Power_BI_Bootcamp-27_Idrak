# %% [markdown]
# ## Dərs 4

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Power BI\Fusion Academy\Pictures\Ders4_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 9):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(15, 5))  # Şəkilin ölçüsü
        plt.title("""DAX: AVERAGEX və FILTER formularının tətbiqi""", fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Card Vizualında göstərmək""", fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(150, 5))  # Şəkilin ölçüsü
        plt.title("""DAX: DATESYTD ilə Kümülatif Cəm (Gün-Gün Cəmləyir)""", fontsize=18, fontweight='bold')
    if i == 3:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Gün-Gün Kümülatif Cəm Vizualı""", fontsize=18, fontweight='bold')
    if i == 4:
        plt.figure(figsize=(15, 6))  # Şəkilin ölçüsü
        plt.title("""Bookmark(Filteri yadda saxlamaq) yaratmaq""", fontsize=18, fontweight='bold')
    if i == 5:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Bookmark-i Aktiv etmək""", fontsize=18, fontweight='bold')
    if i == 6:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Bookmark-ı İşə salmaq""", fontsize=18, fontweight='bold')
    if i == 7:
        plt.figure(figsize=(10, 5))  # Şəkilin ölçüsü
        plt.title("""Mobile layout (Telefon formatı)""", fontsize=18, fontweight='bold')        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
